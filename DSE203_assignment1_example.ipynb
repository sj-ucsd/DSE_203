# %%
# Install newly created package by the team
# The package is available at https://test.pypi.org/project/sstopgraph-pkg/
#!pip install -i https://test.pypi.org/simple/ sstopgraph-pkg

# %%
from sstopgraph import sstopgraph

# %%
# call the package method to convert semi-structured input data to property graph
input_file = './input_files/people.json'
map_cfg_file = './input_files/people_map_cfg.json'
output_file = './output_files/people_pgraph.json'
sstopgraph.semistruct_to_pgraph(input_file, map_cfg_file, output_file,True)
# Out:
# input file = ./input_files/people.json, mapping configuration file = ./input_files/people_map_cfg.json,                output file = ./output_files/people_pgraph.json
# input data:
# {'People': [{'id': 1, 'Name': 'Max', 'Age': 20, 'Gender': 'Male', 'friends': [2, 3]}, {'id': 2, 'Name': 'Alice', 'Age': 25, 'Gender': 'Female', 'friends': [1]}, {'id': 3, 'Name': 'Bob', 'Age': 22, 'Gender': 'Male', 'friends': [1, 4]}, {'id': 4, 'Name': 'Joe', 'Age': 52, 'Gender': 'Male', 'friends': [3]}, {'id': 5, 'Name': 'Van Dyke', 'Age': 42, 'Gender': '', 'friends': [2]}, {'id': 6, 'Name': ['Ken', 'Kennedy', 'Kenneth'], 'Age': 'unknown', 'Gender': 'Male', 'friends': []}, {'id': 7, 'Name': ['Sally'], 'Age': '19', 'Gender': 'Female', 'friends': [2, 1, 3, 6, 5, 4]}, {'id': 8, 'Name': ['Ka‘anapali'], 'Age': '19', 'Gender': 'Not Stated', 'friends': [5, 4]}]}
# mapping configuration:
# ...

# %%
input_file = './input_files/movies.json'
map_cfg_file = './input_files/movies_map_cfg.json'
output_file = './output_files/movies_pgraph.json'
sstopgraph.semistruct_to_pgraph(input_file, map_cfg_file, output_file,True)
# Out:
# input file = ./input_files/movies.json, mapping configuration file = ./input_files/movies_map_cfg.json,                output file = ./output_files/movies_pgraph.json
# input data:
# ...

# %%
input_file = './input_files/books.json'
map_cfg_file = './input_files/books_map_cfg.json'
output_file = './output_files/books_pgraph.json'
sstopgraph.semistruct_to_pgraph(input_file, map_cfg_file, output_file,True)
# Out:
# input file = ./input_files/books.json, mapping configuration file = ./input_files/books_map_cfg.json,                output file = ./output_files/books_pgraph.json
# input data:
# ...
